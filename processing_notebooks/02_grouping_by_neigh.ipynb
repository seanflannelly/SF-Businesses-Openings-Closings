# %% [markdown]
# <a href="https://colab.research.google.com/github/miaflynn/CYPLAN255-Final-Project/blob/main/processing_notebooks/02_grouping_by_neigh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing

# %%
import urllib.request
import importlib
import importlib.util
import pandas as pd
import geopandas as gpd
from shapely import wkt

# load functions
urllib.request.urlretrieve(
    'https://raw.githubusercontent.com/miaflynn/CYPLAN255-Final-Project/main/src/functions.py',
    'functions.py'
)
import functions as fx
importlib.reload(fx)

# load data
import urllib.request

urllib.request.urlretrieve(
    'https://raw.githubusercontent.com/miaflynn/CYPLAN255-Final-Project/main/data/processed/ALL_openings_closings.parquet',
    'ALL_openings_closings.parquet'
)

gdf_open_close = gpd.read_parquet('ALL_openings_closings.parquet')

sf_neigh = gpd.read_file('https://raw.githubusercontent.com/miaflynn/CYPLAN255-Final-Project/main/data/processed/polygons/sf_neighborhoods.geojson')

# run function
result = fx.group_points_by_poly_year(
    gdf_open_close,
    sf_neigh,
    id_col='neighborhood'
)

# %%
result
# Out:
#               neighborhood                                           geometry  \
# 0         Western Addition  MULTIPOLYGON (((-122.42144 37.78557, -122.4213...
# 1         Western Addition  MULTIPOLYGON (((-122.42144 37.78557, -122.4213...
# 2         Western Addition  MULTIPOLYGON (((-122.42144 37.78557, -122.4213...
# 3         Western Addition  MULTIPOLYGON (((-122.42144 37.78557, -122.4213...
# 4         Western Addition  MULTIPOLYGON (((-122.42144 37.78557, -122.4213...
# ..                     ...                                                ...
# 403  Bayview Hunters Point  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...
# 404  Bayview Hunters Point  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...
# 405  Bayview Hunters Point  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...
# 406  Bayview Hunters Point  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...
# 407  Bayview Hunters Point  MULTIPOLYGON (((-122.38158 37.75307, -122.3815...
#
#      year  closed  opened naics_filter
# 0    2016   227.0   303.0          all
# 1    2017   201.0   241.0          all
# 2    2018   501.0   211.0          all
# 3    2019   295.0   246.0          all
# 4    2020   221.0   207.0          all
# ..    ...     ...     ...          ...
# 403  2021   676.0   695.0          all
# 404  2022   729.0   662.0          all
# 405  2023   517.0   617.0          all
# 406  2024   561.0   560.0          all
# 407  2025   387.0   474.0          all
#
# [408 rows x 6 columns]
