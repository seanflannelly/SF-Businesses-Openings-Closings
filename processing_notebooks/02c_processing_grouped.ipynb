# %% [markdown]
# <a href="https://colab.research.google.com/github/miaflynn/CYPLAN255-Final-Project/blob/main/02b_processing_grouped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os


from google.colab import drive
drive.mount('/content/drive')

#uncomment on first run
# !wget https://raw.githubusercontent.com/miaflynn/CYPLAN255-Final-Project/main/functions.py
# import functions as fx

import importlib
importlib.reload(fx)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <module 'functions' from '/content/functions.py'>

# %% [markdown]
# ##Reading in file

# %%
#gdf of opening dates after 2016 concatenated with gdf of closing dates after 2016
gdf_open_close = gpd.read_file("/content/drive/MyDrive/C255_final_project/cleaned/open_close_after_2016.geojson")

# %% [markdown]
# ##Reading in census tracts and block groups

# %%
sf_tracts = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_tracts.geojson')

sf_block_grp = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_block_grp.geojson')

sf_neigh = gpd.read_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_neighborhoods.geojson')

# %%
open_close_neighs_gdf = fx.group_points_by_poly(
    gdf_open_close,
    sf_neigh,
    id_col='neighborhood'
)

open_close_neighs_gdf.to_file('/content/drive/MyDrive/C255_final_project/cleaned/open_close_neighs.geojson', driver='GeoJSON')
