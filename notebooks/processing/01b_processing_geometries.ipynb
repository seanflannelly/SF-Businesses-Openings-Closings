# %% [markdown]
# <a href="https://colab.research.google.com/github/miaflynn/CYPLAN255-Final-Project/blob/main/02b_processing_w_tracts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#neighborhood boundaries from SF OpenData
sf_neigh = gpd.read_file('/content/drive/MyDrive/C255_final_project/raw/sf_neighborhoods.geojson')

# %%
#only keeping neighborhood name
sf_neigh_filt = sf_neigh[['nhood', 'geometry']].rename(columns={'nhood':'neighborhood'})

# %%
#export to cleaned folder
sf_neigh_filt.to_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_neighborhoods.geojson', driver='GeoJSON')

# %%
# # Importing SF geometry
# # URL for 2025 TIGER/Line Place boundaries - info here on
# ## how to use: https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.html
url = "https://www2.census.gov/geo/tiger/TIGER2025/PLACE/tl_2025_06_place.zip"

places = gpd.read_file(url)

# Filtered to SF
sf_poly = places[
    (places["NAME"] == "San Francisco") &
    (places["STATEFP"] == "06")   # 06 = California
]


# eproject to same as our gdf
sf_poly = sf_poly.to_crs(epsg=4326)

# %%
#I added a shp file with census tracts to our folder

tracts_gdf = gpd.read_file(
    "/content/drive/MyDrive/C255_final_project/cb_2020_06_tract_500k"
)

# %%
#checking to make sure all good

tracts_gdf.columns

# simplifying
tracts_gdf = tracts_gdf[["NAME", "NAMELSAD", "STATE_NAME","GEOID", "geometry"]]

# %%
# was getting error with "index_right" - so troubleshooted this
tracts_gdf = tracts_gdf.drop(columns=["index_right", ], errors="ignore")

# %%
sf_tracts = gpd.clip(tracts_gdf.to_crs(sf_poly.crs), sf_poly)

# %%
epc_tracts = gpd.read_file("/content/drive/MyDrive/C255_final_project/raw/epc_tracts.geojson")
epc_tracts_sf = gpd.clip(epc_tracts.to_crs(sf_poly.crs), sf_poly)
epc_tracts_sf.to_file('/content/drive/MyDrive/C255_final_project/cleaned/epc_tracts_sf.geojson', driver='GeoJSON')
sf_poly.to_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_poly.geojson', driver='GeoJSON')

# %%
sf_tracts.to_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_tracts.geojson', driver='GeoJSON')

# %%
sf_block_groups = gpd.read_file('/content/drive/MyDrive/C255_final_project/raw/sf_block_groups.geojson')
sf_block_groups = sf_block_groups.rename(columns={'geoid':'GEOID'})

# %%
cols = [
    'blkgrpce', 'GEOID', 'namelsad', 'geometry'
]
sf_block_groups[cols].to_file('/content/drive/MyDrive/C255_final_project/cleaned/sf_block_grp.geojson', driver='GeoJSON')
